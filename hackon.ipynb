# %%
import pandas as pd

data = pd.read_excel("Cardiac_Outcomes.xlsx",sheet_name=None)

# %%
HospDis = data["Hospitalization_Discharge"]
HospDis.dtypes
# Out:
# inpatient_number                                           int64
# DestinationDischarge                                      object
# admission_ward                                            object
# admission_way                                             object
# discharge_department                                      object
# visit_times                                                int64
# respiratory_support                                       object
# oxygen_inhalation                                         object
# dischargeDay                                               int64
# Admission_date                                    datetime64[ns]
# outcome_during_hospitalization                            object
# death_within_28_days                                       int64
# re_admission_within_28_days                                int64
# death_within_3_months                                      int64
# ...

# %%
PatiHist = data["PatientHistory"]
PatiHist.dtypes
# Out:
# inpatient_number                               int64
# cerebrovascular_disease                        int64
# dementia                                       int64
# Chronic_obstructive_pulmonary_disease          int64
# connective_tissue_disease                      int64
# peptic_ulcer_disease                         float64
# diabetes                                       int64
# moderate_to_severe_chronic_kidney_disease    float64
# hemiplegia                                     int64
# leukemia                                       int64
# malignant_lymphoma                             int64
# solid_tumor                                    int64
# liver_disease                                float64
# AIDS                                           int64
# CCI_score                                    float64
# type_II_respiratory_failure                   object
# acute_renal_failure                            int64
# dtype: object

# %%
DemoGraph = data["Demography"]
DemoGraph.dtypes
# Out:
# inpatient_number      int64
# gender               object
# weight              float64
# height              float64
# BMI                 float64
# occupation           object
# ageCat               object
# dtype: object

# %% [markdown]
# ```
# **1,How many patients were registered in each unique occupation?**
# ```

# %%
uniqPati = DemoGraph.groupby('occupation')
uniqPati.dtypes
# Out:
#               inpatient_number  gender   weight   height      BMI occupation  \
# occupation
# Officer                  int64  object  float64  float64  float64     object
# Others                   int64  object  float64  float64  float64     object
# UrbanResident            int64  object  float64  float64  float64     object
# farmer                   int64  object  float64  float64  float64     object
# worker                   int64  object  float64  float64  float64     object
#
#                ageCat
# occupation
# Officer        object
# Others         object
# UrbanResident  object
# farmer         object
# worker         object

# %%
uniqPati.agg({'inpatient_number':'count'})
# Out:
#                inpatient_number
# occupation
# Officer                       7
# Others                       89
# UrbanResident              1670
# farmer                      198
# worker                       17

# %%
uniqPati = DemoGraph.groupby('occupation').agg({'inpatient_number':'count'})
uniqPati
# Out:
#                inpatient_number
# occupation
# Officer                       7
# Others                       89
# UrbanResident              1670
# farmer                      198
# worker                       17

# %%
# @title inpatient_number

from matplotlib import pyplot as plt
uniqPati['inpatient_number'].plot(kind='hist', bins=20, title='inpatient_number')
plt.gca().spines[['top', 'right',]].set_visible(False)
